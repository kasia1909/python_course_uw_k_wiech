# %%
import pandas as pd

leadername = ['Stanisław', 'Jan', 'Jan', 'Grzegorz', 'Jan']
leadersurname = ['Żółkiewski', 'Chodkiewicz', 'Sobieski', 'Chodkiewicz', 'Chodkiewicz']
battle = ['Kłuszyn 4.VII.1610', 'Kircholm 27.IX.1605', 'Wiedeń 12.IX.1683 | Chocim 11.XI.1673','Czaśniki 26.I.1564','Biały Kamień 25.IX.1604']
btype = ['land battle']*5
no = ['old slavic','hebrew','hebrew','greek','hebrew']
title = ['hetman wielki koronny','hetman wielki litewski','król','hetman wielki litewski','hetman wielki litewski']

ln = pd.Series(leadername)
ls = pd.Series(leadersurname)
b = pd.Series(battle)
bt = pd.Series(btype)
o = pd.Series(no)
t = pd.Series(title)

data = pd.DataFrame({'Leader Name': ln, 'Leader Surname': ls, 'Battle': b, 'Battle type': bt,
                     'Name origin': o, 'Title':t})
data
# Out:
#   Leader Name Leader Surname                                 Battle  \
# 0   Stanisław     Żółkiewski                     Kłuszyn 4.VII.1610
# 1         Jan    Chodkiewicz                    Kircholm 27.IX.1605
# 2         Jan       Sobieski  Wiedeń 12.IX.1683 | Chocim 11.XI.1673
# 3    Grzegorz    Chodkiewicz                     Czaśniki 26.I.1564
# 4         Jan    Chodkiewicz                Biały Kamień 25.IX.1604
#
#    Battle type Name origin                   Title
# 0  land battle  old slavic   hetman wielki koronny
# 1  land battle      hebrew  hetman wielki litewski
# 2  land battle      hebrew                    król
# 3  land battle       greek  hetman wielki litewski
# 4  land battle      hebrew  hetman wielki litewski

# %%
data = data.drop(data.index[2])
data
# Out:
#   Leader Name Leader Surname                   Battle  Battle type  \
# 0   Stanisław     Żółkiewski       Kłuszyn 4.VII.1610  land battle
# 1         Jan    Chodkiewicz      Kircholm 27.IX.1605  land battle
# 3    Grzegorz    Chodkiewicz       Czaśniki 26.I.1564  land battle
# 4         Jan    Chodkiewicz  Biały Kamień 25.IX.1604  land battle
#
#   Name origin                   Title
# 0  old slavic   hetman wielki koronny
# 1      hebrew  hetman wielki litewski
# 3       greek  hetman wielki litewski
# 4      hebrew  hetman wielki litewski

# %%
dataframe2 = {'Leader Name': 'Jan', 'Leader Surname': 'Sobieski', 'Battle': 'Wiedeń 12.IX.1683', 'Battle type': 'land battle', 'Name origin': 'hebrew', 'Title': 'król'}
data = data.append(dataframe2,ignore_index = True)
data
# Out:
#   Leader Name Leader Surname                   Battle  Battle type  \
# 0   Stanisław     Żółkiewski       Kłuszyn 4.VII.1610  land battle
# 1         Jan    Chodkiewicz      Kircholm 27.IX.1605  land battle
# 2    Grzegorz    Chodkiewicz       Czaśniki 26.I.1564  land battle
# 3         Jan    Chodkiewicz  Biały Kamień 25.IX.1604  land battle
# 4         Jan       Sobieski        Wiedeń 12.IX.1683  land battle
#
#   Name origin                   Title
# 0  old slavic   hetman wielki koronny
# 1      hebrew  hetman wielki litewski
# 2       greek  hetman wielki litewski
# 3      hebrew  hetman wielki litewski
# 4      hebrew                    król

# %%
dataframe3 = {'Leader Name': 'Jan', 'Leader Surname': 'Sobieski', 'Battle': 'Chocim 11.XI.1673', 'Battle type': 'land battle', 'Name origin': 'hebrew', 'Title': 'król'}

# %%
data = data.append(dataframe3, ignore_index = True)
data
# Out:
#   Leader Name Leader Surname                   Battle  Battle type  \
# 0   Stanisław     Żółkiewski       Kłuszyn 4.VII.1610  land battle
# 1         Jan    Chodkiewicz      Kircholm 27.IX.1605  land battle
# 2    Grzegorz    Chodkiewicz       Czaśniki 26.I.1564  land battle
# 3         Jan    Chodkiewicz  Biały Kamień 25.IX.1604  land battle
# 4         Jan       Sobieski        Wiedeń 12.IX.1683  land battle
# 5         Jan       Sobieski        Chocim 11.XI.1673  land battle
#
#   Name origin                   Title
# 0  old slavic   hetman wielki koronny
# 1      hebrew  hetman wielki litewski
# 2       greek  hetman wielki litewski
# 3      hebrew  hetman wielki litewski
# 4      hebrew                    król
# 5      hebrew                    król

# %%
battles = data.iloc[:, 2:4]
battles
# Out:
#                     Battle  Battle type
# 0       Kłuszyn 4.VII.1610  land battle
# 1      Kircholm 27.IX.1605  land battle
# 2       Czaśniki 26.I.1564  land battle
# 3  Biały Kamień 25.IX.1604  land battle
# 4        Wiedeń 12.IX.1683  land battle
# 5        Chocim 11.XI.1673  land battle

# %%
leaders = data.drop(columns=['Battle','Battle type'])
leaders
# Out:
#   Leader Name Leader Surname Name origin                   Title
# 0   Stanisław     Żółkiewski  old slavic   hetman wielki koronny
# 1         Jan    Chodkiewicz      hebrew  hetman wielki litewski
# 2    Grzegorz    Chodkiewicz       greek  hetman wielki litewski
# 3         Jan    Chodkiewicz      hebrew  hetman wielki litewski
# 4         Jan       Sobieski      hebrew                    król
# 5         Jan       Sobieski      hebrew                    król

# %%
leaders_no_dupes = leaders.drop(index=[1,5])
leaders_no_dupes
# Out:
#   Leader Name Leader Surname Name origin                   Title
# 0   Stanisław     Żółkiewski  old slavic   hetman wielki koronny
# 2    Grzegorz    Chodkiewicz       greek  hetman wielki litewski
# 3         Jan    Chodkiewicz      hebrew  hetman wielki litewski
# 4         Jan       Sobieski      hebrew                    król

# %%
leaders_names = leaders_no_dupes
leaders_names['Leader Name, Surname'] = leaders_names[['Leader Name', 'Leader Surname']].agg(' '.join, axis=1)
leaders_names = leaders_names.drop(columns=['Leader Name','Leader Surname'])
leaders_names = leaders_names[['Leader Name, Surname', 'Name origin', 'Title']]
leaders_names
# Out:
#    Leader Name, Surname Name origin                   Title
# 0  Stanisław Żółkiewski  old slavic   hetman wielki koronny
# 2  Grzegorz Chodkiewicz       greek  hetman wielki litewski
# 3       Jan Chodkiewicz      hebrew  hetman wielki litewski
# 4          Jan Sobieski      hebrew                    król

# %%
test = leaders_names
# Out:
#    Leader Name, Surname Name origin                   Title
# 0  Stanisław Żółkiewski  old slavic   hetman wielki koronny
# 2  Grzegorz Chodkiewicz       greek  hetman wielki litewski
# 3       Jan Chodkiewicz      hebrew  hetman wielki litewski
# 4          Jan Sobieski      hebrew                    król

# %%
ex_3 = test.join(battles,how='right')
import numpy as np

# %%
ex_3.loc[2:2,'Leader Name, Surname', 'Name origin', 'Title'] = 'Jan Chodkiewicz', 'hebrew', 'hetman wielki litewski'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-626e0ff0bc0a> in <module>
# ----> 1 ex_3.loc[2:2,'Leader Name, Surname', 'Name origin', 'Title'] = 'Jan Chodkiewicz', 'hebrew', 'hetman wielki litewski'
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     664         else:
#     665             key = com.apply_if_callable(key, self.obj)
# --> 666         indexer = self._get_setitem_indexer(key)
#     667         self._has_valid_setitem_indexer(key)
#     668
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     615
#     616         try:
# --> 617             return self._convert_to_indexer(key, axis=0, is_setter=True)
#     618         except TypeError as e:
#     619
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, key, axis, is_setter)
#    1196             else:
#    1197                 # When setting, missing keys are not allowed, even with .loc:
# -> 1198                 return self._get_listlike_indexer(key, axis, raise_missing=True)[1]
#    1199         else:
#    1200             try:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1247
#    1248         if ax.is_unique and not getattr(ax, "is_overlapping", False):
# -> 1249             indexer = ax.get_indexer_for(keyarr)
#    1250             keyarr = ax.reindex(keyarr)[0]
#    1251         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer_for(self, target, **kwargs)
#    4711         """
#    4712         if self.is_unique:
# -> 4713             return self.get_indexer(target, **kwargs)
#    4714         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    4715         return indexer
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_indexer(self, target, method, limit, tolerance)
#     376         if not (is_integer_dtype(target_array) and target_array.ndim == 1):
#     377             # checks/conversions/roundings are delegated to general method
# --> 378             return super().get_indexer(target, method=method, tolerance=tolerance)
#     379
#     380         locs = target_array - start
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    2979             this = self.astype(object)
#    2980             target = target.astype(object)
# -> 2981             return this.get_indexer(
#    2982                 target, method=method, limit=limit, tolerance=tolerance
#    2983             )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_indexer(self, target, method, limit, tolerance)
#    3004                 )
#    3005
# -> 3006             indexer = self._engine.get_indexer(target._get_engine_target())
#    3007
#    3008         return ensure_platform_int(indexer)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_indexer()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.lookup()
#
# TypeError: unhashable type: 'slice'
